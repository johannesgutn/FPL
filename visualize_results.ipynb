# %%
from main_functions import *
# Out:
# 2023-03-07 15:50:00.750459: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# This shows the preductions for all the players
df = pd.read_csv(f'player_data/player_data_{season}_{last_GW}.csv')
df.head(20)
# Out:
#         web_name opponent_27  predicted_points_27 opponent_28  \
# 0          Toney         SOU                14.47         LEI
# 1          March         LEE                12.38           0
# 2       Nørgaard         SOU                10.85         LEI
# 3           Raya         EVE                10.69         LEI
# 4         Mitoma         CRY                12.40           0
# 5        Pinnock         SOU                 9.76         LEI
# 6      Estupiñán         CRY                12.79           0
# 7         Hickey         SOU                 9.34         LEI
# 8        Webster         LEE                12.20           0
# 9         Mbeumo         SOU                 9.39         LEI
# 10        Jensen         EVE                 9.01         LEI
# 11      Scherpen         CRY                11.07           0
# 12       Veltman         LEE                11.82           0
# 13         Undav         LEE                 9.88           0
# 14        Steele         LEE                10.55           0
# 15  Mac Allister         CRY                 9.76           0
# 16       Welbeck         CRY                10.87           0
# 17           Cox         SOU                 9.04         LEI
# 18          Dunk         CRY                11.04           0
# 19         Wissa         EVE                 8.54         LEI
#
#     predicted_points_28 opponent_29  predicted_points_29 opponent_30  \
# 0                  8.22         BHA                12.74         NEW
# 1                  0.00         BRE                12.73         TOT
# 2                  5.20         MUN                 9.96         NEW
# 3                  4.17         BHA                10.38         NEW
# 4                  0.00         BRE                13.45         TOT
# 5                  4.90         MUN                10.96         NEW
# 6                  0.00         BOU                11.16         TOT
# 7                  4.93         MUN                10.94         NEW
# 8                  0.00         BOU                11.51         TOT
# 9                  4.94         BHA                 8.58         NEW
# 10                 4.70         BHA                 9.75         NEW
# 11                 0.00         BRE                12.36         TOT
# 12                 0.00         BRE                10.98         TOT
# 13                 0.00         BRE                12.44         TOT
# 14                 0.00         BOU                10.42         TOT
# 15                 0.00         BOU                12.20         TOT
# 16                 0.00         BOU                10.97         TOT
# 17                 3.47         MUN                 8.24         NEW
# 18                 0.00         BRE                10.20         TOT
# 19                 3.93         BHA                 8.68         NEW
#
#     predicted_points_30 opponent_31  ...  \
# 0                  5.22         WOL  ...
# 1                  5.59         CHE  ...
# 2                  2.79         WOL  ...
# 3                  2.58         WOL  ...
# 4                  5.15         CHE  ...
# 5                  2.10         WOL  ...
# 6                  5.19         CHE  ...
# 7                  1.05         WOL  ...
# 8                  5.03         CHE  ...
# 9                  2.93         WOL  ...
# 10                 2.74         WOL  ...
# 11                 5.22         CHE  ...
# 12                 4.53         CHE  ...
# 13                 4.79         CHE  ...
# 14                 5.15         CHE  ...
# 15                 4.70         CHE  ...
# 16                 4.48         CHE  ...
# 17                 2.77         WOL  ...
# 18                 4.84         CHE  ...
# 19                 2.45         WOL  ...
#
#     opp_creativity_conceded_pg_atk_last5  opp_threat_conceded_pg_atk_last5  \
# 0                                  143.1                             119.0
# 1                                   92.6                              95.5
# 2                                  143.1                             119.0
# 3                                  143.1                             119.0
# 4                                   92.6                              95.5
# 5                                  143.1                             119.0
# 6                                   92.6                              95.5
# 7                                  143.1                             119.0
# 8                                   92.6                              95.5
# 9                                  143.1                             119.0
# 10                                 143.1                             119.0
# 11                                  92.6                              95.5
# 12                                  92.6                              95.5
# 13                                  92.6                              95.5
# 14                                  92.6                              95.5
# 15                                  92.6                              95.5
# 16                                  92.6                              95.5
# 17                                 143.1                             119.0
# 18                                  92.6                              95.5
# 19                                 143.1                             119.0
#
#     opp_bps_conceded_pg_atk_last5  opp_total_points_conceded_pg_def_last5  \
# 0                            94.2                                    31.0
# 1                            85.8                                    34.0
# 2                            94.2                                    31.0
# 3                            94.2                                    31.0
# 4                            85.8                                    34.0
# 5                            94.2                                    31.0
# 6                            85.8                                    34.0
# 7                            94.2                                    31.0
# 8                            85.8                                    34.0
# 9                            94.2                                    31.0
# 10                           94.2                                    31.0
# 11                           85.8                                    34.0
# 12                           85.8                                    34.0
# 13                           85.8                                    34.0
# 14                           85.8                                    34.0
# 15                           85.8                                    34.0
# 16                           85.8                                    34.0
# 17                           94.2                                    31.0
# 18                           85.8                                    34.0
# 19                           94.2                                    31.0
#
#     opp_ict_index_conceded_pg_def_last5  opp_influence_conceded_pg_def_last5  \
# 0                                  24.9                                123.4
# 1                                  18.8                                128.6
# 2                                  24.9                                123.4
# 3                                  24.9                                123.4
# 4                                  18.8                                128.6
# 5                                  24.9                                123.4
# 6                                  18.8                                128.6
# 7                                  24.9                                123.4
# 8                                  18.8                                128.6
# 9                                  24.9                                123.4
# 10                                 24.9                                123.4
# 11                                 18.8                                128.6
# 12                                 18.8                                128.6
# 13                                 18.8                                128.6
# 14                                 18.8                                128.6
# 15                                 18.8                                128.6
# 16                                 18.8                                128.6
# 17                                 24.9                                123.4
# 18                                 18.8                                128.6
# 19                                 24.9                                123.4
#
#     opp_creativity_conceded_pg_def_last5  opp_threat_conceded_pg_def_last5  \
# 0                                   70.5                              54.6
# 1                                   29.6                              30.0
# 2                                   70.5                              54.6
# 3                                   70.5                              54.6
# 4                                   29.6                              30.0
# 5                                   70.5                              54.6
# 6                                   29.6                              30.0
# 7                                   70.5                              54.6
# 8                                   29.6                              30.0
# 9                                   70.5                              54.6
# 10                                  70.5                              54.6
# 11                                  29.6                              30.0
# 12                                  29.6                              30.0
# 13                                  29.6                              30.0
# 14                                  29.6                              30.0
# 15                                  29.6                              30.0
# 16                                  29.6                              30.0
# 17                                  70.5                              54.6
# 18                                  29.6                              30.0
# 19                                  70.5                              54.6
#
#     opp_bps_conceded_pg_def_last5  X_points
# 0                           136.6      9.88
# 1                           139.2      5.50
# 2                           136.6      6.52
# 3                           136.6      7.41
# 4                           139.2      3.76
# 5                           136.6      6.80
# 6                           139.2      4.64
# 7                           136.6      6.74
# 8                           139.2      3.88
# 9                           136.6      6.72
# 10                          136.6      6.18
# 11                          139.2      3.35
# 12                          139.2      3.74
# 13                          139.2      3.44
# 14                          139.2      4.33
# 15                          139.2      3.74
# 16                          139.2      3.97
# 17                          136.6      6.61
# 18                          139.2      3.74
# 19                          136.6      6.07
#
# [20 rows x 158 columns]

# %%
# This shows your team
df = pd.read_csv(f'ml_team/ml_team_{season}_{next_GW}.csv')
df.head(20)
# Out:
#       web_name     id  element_type  form  points_per_game  \
# 0        Toney   80.0             4   6.3              5.9
# 1        March  107.0             3   5.0              4.7
# 2         Raya   81.0             1   3.7              4.5
# 3       Mitoma  124.0             3   5.7              4.7
# 4      Pinnock   92.0             2   3.7              3.4
# 5   Martinelli   19.0             3   6.5              5.5
# 6      Haaland  318.0             4   4.7              7.9
# 7         Saka   13.0             3   6.3              5.7
# 8         Kane  427.0             4   4.6              6.3
# 9         Ward  254.0             1   4.5              3.6
# 10    Castagne  258.0             2   2.5              3.3
# 11    Maddison  261.0             3   3.5              5.5
# 12       Schär  366.0             2   1.0              4.6
# 13    Trippier  357.0             2   1.3              6.1
# 14   Zinchenko  313.0             2   4.8              4.2
#
#     predicted_points_27  predicted_points_mean  predicted_points_27_raw  \
# 0                 14.47                  10.11                    14.47
# 1                 12.38                   7.24                    12.38
# 2                 10.69                   7.05                    10.69
# 3                 12.40                   6.95                    12.40
# 4                  9.76                   6.90                     9.76
# 5                  3.77                   4.64                     3.77
# 6                  5.71                   4.16                     5.71
# 7                  2.63                   3.78                     2.63
# 8                  3.52                   3.64                     3.52
# 9                  2.74                   3.30                     2.74
# 10                 3.26                   3.27                     3.26
# 11                 2.74                   3.16                     2.74
# 12                 4.10                   3.02                     5.47
# 13                 3.92                   2.74                     3.92
# 14                 2.01                   2.62                     2.01
#
#     predicted_points_mean_raw
# 0                       10.11
# 1                        7.24
# 2                        7.05
# 3                        6.95
# 4                        6.90
# 5                        4.64
# 6                        4.16
# 7                        3.78
# 8                        3.64
# 9                        3.30
# 10                       3.27
# 11                       3.16
# 12                       4.03
# 13                       2.74
# 14                       2.62
