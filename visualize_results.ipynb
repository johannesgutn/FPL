# %%
from main_functions import *

# %%
# This shows the preductions for all the players
df = pd.read_csv(f'player_data/player_data_{season}_{last_GW}.csv')
df.head(20)
# Out:
#           web_name opponent_6  predicted_points_6 opponent_7  \
# 0             Doku        NFO                6.18        WOL
# 1             Saka        TOT                6.22        BOU
# 2            Salah        WHU                5.61        TOT
# 3        J.Alvarez        NFO                7.53        WOL
# 4         Rashford        BUR                5.45        CRY
# 5         Maddison        ARS                5.57        LIV
# 6           Mbeumo        EVE                4.70        NFO
# 7         Sterling        AVL                5.36        FUL
# 8           Adrián        WHU                5.57        TOT
# 9         Kelleher        WHU                5.57        TOT
# 10           Bowen        LIV                4.55        SHU
# 11           Diaby        CHE                5.44        BHA
# 12           Macey        WOL                3.84        EVE
# 13          Walton        WOL                3.84        EVE
# 14           Foden        NFO                5.52        WOL
# 15         Rodrigo        NFO                6.37        WOL
# 16           Gross        BOU                5.62        AVL
# 17      Szoboszlai        WHU                5.62        TOT
# 18      Kulusevski        ARS                5.45        LIV
# 19  Francis-Clarke        WOL                3.85        EVE
#
#     predicted_points_7 opponent_8  predicted_points_8 opponent_9  \
# 0                 7.99        ARS                5.16        BHA
# 1                 5.37        MCI                6.37        CHE
# 2                 4.55        BHA                5.79        EVE
# 3                 3.49        ARS                7.08        BHA
# 4                 6.84        BRE                4.61        SHU
# 5                 5.80        LUT                5.34        FUL
# 6                 8.38        MUN                5.50        BUR
# 7                 6.29        BUR                4.10        ARS
# 8                 5.58        BHA                4.03        EVE
# 9                 5.58        BHA                4.03        EVE
# 10                5.26        NEW                6.16        AVL
# 11                4.28        WOL                4.25        WHU
# 12                8.85        TOT                4.72        NFO
# 13                8.85        TOT                4.72        NFO
# 14                4.35        ARS                5.17        BHA
# 15                4.85        ARS                4.36        BHA
# 16                4.60        LIV                5.08        MCI
# 17                4.20        BHA                3.74        EVE
# 18                4.28        LUT                4.74        FUL
# 19                8.49        TOT                4.57        NFO
#
#     predicted_points_9 opponent_10  ...  opp_creativity_conceded_pg_atk_last5  \
# 0                 5.54         MUN  ...                                 142.4
# 1                 6.52         SHU  ...                                 192.4
# 2                 6.09         NFO  ...                                 141.3
# 3                 6.28         MUN  ...                                 142.4
# 4                 6.09         MCI  ...                                  52.2
# 5                 5.80         CRY  ...                                 107.1
# 6                 4.55         CHE  ...                                  79.8
# 7                 5.68         BRE  ...                                  96.5
# 8                 5.61         NFO  ...                                 141.3
# 9                 5.61         NFO  ...                                 141.3
# 10                4.09         EVE  ...                                  99.5
# 11                6.39         LUT  ...                                 132.1
# 12                4.54         AVL  ...                                  92.0
# 13                4.54         AVL  ...                                  92.0
# 14                5.27         MUN  ...                                 142.4
# 15                4.75         MUN  ...                                 142.4
# 16                3.97         FUL  ...                                 119.9
# 17                5.48         NFO  ...                                 141.3
# 18                5.60         CRY  ...                                 107.1
# 19                4.61         AVL  ...                                  92.0
#
#     opp_threat_conceded_pg_atk_last5  opp_bps_conceded_pg_atk_last5  \
# 0                              152.4                          114.8
# 1                              199.2                          110.2
# 2                              124.8                           97.0
# 3                              152.4                          114.8
# 4                               44.0                           46.0
# 5                               94.4                           92.6
# 6                               92.4                           74.0
# 7                              114.6                           73.2
# 8                              124.8                           97.0
# 9                              124.8                           97.0
# 10                             119.6                          104.6
# 11                             148.2                          130.5
# 12                             113.4                          106.8
# 13                             113.4                          106.8
# 14                             152.4                          114.8
# 15                             152.4                          114.8
# 16                             156.8                          118.2
# 17                             124.8                           97.0
# 18                              94.4                           92.6
# 19                             113.4                          106.8
#
#     opp_total_points_conceded_pg_def_last5  \
# 0                                     17.2
# 1                                     18.0
# 2                                      8.4
# 3                                     17.2
# 4                                     10.6
# 5                                     14.6
# 6                                     24.0
# 7                                     17.0
# 8                                      8.4
# 9                                      8.4
# 10                                    30.8
# 11                                    27.5
# 12                                    12.0
# 13                                    12.0
# 14                                    17.2
# 15                                    17.2
# 16                                    16.6
# 17                                     8.4
# 18                                    14.6
# 19                                    12.0
#
#     opp_ict_index_conceded_pg_def_last5  opp_influence_conceded_pg_def_last5  \
# 0                                  21.7                                140.4
# 1                                  22.7                                116.3
# 2                                  16.5                                107.7
# 3                                  21.7                                140.4
# 4                                  13.5                                101.0
# 5                                  12.9                                 88.7
# 6                                  16.2                                120.3
# 7                                  17.3                                110.1
# 8                                  16.5                                107.7
# 9                                  16.5                                107.7
# 10                                 19.7                                131.4
# 11                                 22.2                                116.4
# 12                                 15.8                                 89.2
# 13                                 15.8                                 89.2
# 14                                 21.7                                140.4
# 15                                 21.7                                140.4
# 16                                 17.9                                 97.3
# 17                                 16.5                                107.7
# 18                                 12.9                                 88.7
# 19                                 15.8                                 89.2
#
#     opp_creativity_conceded_pg_def_last5  opp_threat_conceded_pg_def_last5  \
# 0                                   44.7                              31.4
# 1                                   71.6                              39.0
# 2                                   32.7                              23.8
# 3                                   44.7                              31.4
# 4                                   11.1                              23.0
# 5                                   28.3                              12.2
# 6                                   25.6                              16.0
# 7                                   44.0                              19.6
# 8                                   32.7                              23.8
# 9                                   32.7                              23.8
# 10                                  39.7                              25.2
# 11                                  66.8                              38.2
# 12                                  55.7                              13.0
# 13                                  55.7                              13.0
# 14                                  44.7                              31.4
# 15                                  44.7                              31.4
# 16                                  43.1                              38.4
# 17                                  32.7                              23.8
# 18                                  28.3                              12.2
# 19                                  55.7                              13.0
#
#     opp_bps_conceded_pg_def_last5  X_points
# 0                            94.6      6.52
# 1                            95.8      4.97
# 2                            68.0      7.16
# 3                            94.6      4.18
# 4                            76.2      5.54
# 5                            77.0      5.33
# 6                            96.8      4.54
# 7                            87.8      4.93
# 8                            68.0      5.04
# 9                            68.0      5.04
# 10                          130.0      5.63
# 11                          119.2      5.19
# 12                           82.6      3.60
# 13                           82.6      3.60
# 14                           94.6      5.13
# 15                           94.6      5.06
# 16                           82.6      6.13
# 17                           68.0      6.30
# 18                           77.0      5.20
# 19                           82.6      3.65
#
# [20 rows x 158 columns]

# %%
# This shows your team
df = pd.read_csv(f'ml_team/ml_team_{season}_{next_GW}.csv')
df.head(20)
# Out:
#        web_name     id  element_type  form  points_per_game  \
# 0          Doku  678.0             3   3.7              5.5
# 1          Saka   19.0             3   6.0              6.2
# 2      Rashford  396.0             3   5.3              4.2
# 3     J.Alvarez  343.0             4   8.3              7.4
# 4     N.Jackson  211.0             4   3.0              2.2
# 5   B.Fernandes  373.0             3   5.0              3.8
# 6       Haaland  355.0             4  10.0              9.0
# 7      Chilwell  195.0             2   2.3              3.0
# 8     Estupiñan  131.0             2   1.0              5.2
# 9      Andersen  220.0             2   4.3              4.8
# 10       Mitoma  143.0             3   2.7              5.0
# 11       Turner   28.0             1   3.3              2.8
# 12        Digne   42.0             2   3.7              4.0
# 13        Onana  597.0             1   0.7              2.6
# 14      Baldock  473.0             2   0.7              1.3
#
#     predicted_points_6  predicted_points_mean  predicted_points_6_raw  \
# 0                 6.18                   6.28                    6.18
# 1                 6.22                   5.89                    6.22
# 2                 5.45                   5.71                    5.45
# 3                 7.53                   5.71                    7.53
# 4                 6.47                   4.97                    6.47
# 5                 4.36                   4.77                    4.36
# 6                 7.44                   4.64                    7.44
# 7                 4.66                   4.18                    4.66
# 8                 4.24                   4.02                    4.24
# 9                 3.20                   4.01                    3.20
# 10                3.63                   3.90                    3.63
# 11                3.26                   3.51                    3.26
# 12                3.92                   3.31                    3.92
# 13                3.58                   2.70                    5.12
# 14                0.38                   0.34                    2.17
#
#     predicted_points_mean_raw
# 0                        6.28
# 1                        5.89
# 2                        5.71
# 3                        5.71
# 4                        4.97
# 5                        4.77
# 6                        4.64
# 7                        4.18
# 8                        4.02
# 9                        4.01
# 10                       3.90
# 11                       3.51
# 12                       3.31
# 13                       3.86
# 14                       1.90
