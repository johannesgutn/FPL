# %%
from main_functions import *

# %%
# This shows the preductions for all the players
df = pd.read_csv(f'player_data/player_data_{season}_{last_GW}.csv')
df.head(20)
# Out:
#       web_name opponent_21  predicted_points_21 opponent_22  \
# 0     Ødegaard         MUN                 7.13         EVE
# 1     Trippier         CRY                10.58         WHU
# 2    De Bruyne         WOL                 5.11         TOT
# 3         Saka         MUN                 6.58         EVE
# 4      Haaland         WOL                 6.90         TOT
# 5       Mahrez         WOL                 5.18         TOT
# 6   Martinelli         MUN                 7.16         EVE
# 7        March         LEI                 6.82         BOU
# 8         Kane         FUL                 8.31         MCI
# 9     Grealish         WOL                 5.00         TOT
# 10      Ortega         WOL                 7.02         TOT
# 11      Carson         WOL                 7.02         TOT
# 12     Almirón         CRY                 7.63         WHU
# 13   Fernandes         ARS                 6.41         CRY
# 14    Trossard         LEI                 6.05         BOU
# 15       Salah         CHE                 7.06         WOL
# 16       White         MUN                 5.53         EVE
# 17        Isak         CRY                 9.05         WHU
# 18         Son         FUL                 7.48         MCI
# 19     Laporte         WOL                 5.35         TOT
#
#     predicted_points_22 opponent_23  predicted_points_23 opponent_24  \
# 0                  8.65         BRE                12.51         AVL
# 1                  8.75         BOU                 8.23         LIV
# 2                  5.99         AVL                13.32         NFO
# 3                  8.34         MCI                10.58         AVL
# 4                  5.80         ARS                10.11         NFO
# 5                  7.22         ARS                11.01         NFO
# 6                  5.46         MCI                10.45         AVL
# 7                  7.16         CRY                 7.33         FUL
# 8                  5.36         LEI                 7.38         WHU
# 9                  4.81         ARS                10.05         NFO
# 10                 4.83         AVL                10.17         NFO
# 11                 4.83         AVL                10.17         NFO
# 12                 6.12         BOU                 7.11         LIV
# 13                 8.19         LEE                 7.10         LEI
# 14                 7.34         CRY                 7.18         FUL
# 15                 5.82         EVE                 4.17         NEW
# 16                 5.27         BRE                 7.50         AVL
# 17                 6.40         BOU                 7.04         LIV
# 18                 4.50         LEI                 6.49         WHU
# 19                 5.36         ARS                 8.71         NFO
#
#     predicted_points_24 opponent_25  ...  opp_influence_conceded_pg_atk_last5  \
# 0                  7.85         LEI  ...                                 60.8
# 1                  7.29         BHA  ...                                182.5
# 2                  6.58         BOU  ...                                100.9
# 3                  7.40         LEI  ...                                 60.8
# 4                  7.52         BOU  ...                                100.9
# 5                  7.24         BOU  ...                                100.9
# 6                  6.16         LEI  ...                                 60.8
# 7                  7.44         NEW  ...                                 95.9
# 8                  6.44         CHE  ...                                129.4
# 9                  6.79         BOU  ...                                100.9
# 10                 5.65         BOU  ...                                100.9
# 11                 5.65         BOU  ...                                100.9
# 12                 6.61         BHA  ...                                182.5
# 13                 4.95         BRE  ...                                 93.1
# 14                 6.56         NEW  ...                                 95.9
# 15                 6.36         CRY  ...                                152.8
# 16                 7.82         LEI  ...                                 60.8
# 17                 5.52         BHA  ...                                182.5
# 18                 5.49         CHE  ...                                129.4
# 19                 5.58         BOU  ...                                100.9
#
#     opp_creativity_conceded_pg_atk_last5  opp_threat_conceded_pg_atk_last5  \
# 0                                   59.0                             108.4
# 1                                  158.4                             195.2
# 2                                  109.5                             147.8
# 3                                   59.0                             108.4
# 4                                  109.5                             147.8
# 5                                  109.5                             147.8
# 6                                   59.0                             108.4
# 7                                   80.6                             118.6
# 8                                  139.7                             177.8
# 9                                  109.5                             147.8
# 10                                 109.5                             147.8
# 11                                 109.5                             147.8
# 12                                 158.4                             195.2
# 13                                  93.3                             113.8
# 14                                  80.6                             118.6
# 15                                 147.7                             154.0
# 16                                  59.0                             108.4
# 17                                 158.4                             195.2
# 18                                 139.7                             177.8
# 19                                 109.5                             147.8
#
#     opp_bps_conceded_pg_atk_last5  opp_total_points_conceded_pg_def_last5  \
# 0                            51.0                                     8.6
# 1                           140.6                                    37.0
# 2                            74.8                                    23.6
# 3                            51.0                                     8.6
# 4                            74.8                                    23.6
# 5                            74.8                                    23.6
# 6                            51.0                                     8.6
# 7                            77.8                                    20.4
# 8                           110.0                                    18.0
# 9                            74.8                                    23.6
# 10                           74.8                                    23.6
# 11                           74.8                                    23.6
# 12                          140.6                                    37.0
# 13                           76.6                                    12.4
# 14                           77.8                                    20.4
# 15                          109.0                                    31.8
# 16                           51.0                                     8.6
# 17                          140.6                                    37.0
# 18                          110.0                                    18.0
# 19                           74.8                                    23.6
#
#     opp_ict_index_conceded_pg_def_last5  opp_influence_conceded_pg_def_last5  \
# 0                                  13.1                                 87.6
# 1                                  22.4                                149.3
# 2                                  17.0                                 97.4
# 3                                  13.1                                 87.6
# 4                                  17.0                                 97.4
# 5                                  17.0                                 97.4
# 6                                  13.1                                 87.6
# 7                                  13.9                                 72.9
# 8                                  19.4                                128.4
# 9                                  17.0                                 97.4
# 10                                 17.0                                 97.4
# 11                                 17.0                                 97.4
# 12                                 22.4                                149.3
# 13                                 18.1                                114.2
# 14                                 13.9                                 72.9
# 15                                 25.0                                165.0
# 16                                 13.1                                 87.6
# 17                                 22.4                                149.3
# 18                                 19.4                                128.4
# 19                                 17.0                                 97.4
#
#     opp_creativity_conceded_pg_def_last5  opp_threat_conceded_pg_def_last5  \
# 0                                   27.8                              15.2
# 1                                   43.1                              30.8
# 2                                   40.8                              31.2
# 3                                   27.8                              15.2
# 4                                   40.8                              31.2
# 5                                   40.8                              31.2
# 6                                   27.8                              15.2
# 7                                   52.7                              13.4
# 8                                   46.2                              18.6
# 9                                   40.8                              31.2
# 10                                  40.8                              31.2
# 11                                  40.8                              31.2
# 12                                  43.1                              30.8
# 13                                  40.4                              26.2
# 14                                  52.7                              13.4
# 15                                  43.8                              40.6
# 16                                  27.8                              15.2
# 17                                  43.1                              30.8
# 18                                  46.2                              18.6
# 19                                  40.8                              31.2
#
#     opp_bps_conceded_pg_def_last5
# 0                            59.4
# 1                           150.2
# 2                           102.8
# 3                            59.4
# 4                           102.8
# 5                           102.8
# 6                            59.4
# 7                            89.0
# 8                           107.4
# 9                           102.8
# 10                          102.8
# 11                          102.8
# 12                          150.2
# 13                           93.2
# 14                           89.0
# 15                          138.2
# 16                           59.4
# 17                          150.2
# 18                          107.4
# 19                          102.8
#
# [20 rows x 157 columns]

# %%
# This shows your team
df = pd.read_csv(f'ml_team/ml_team_{season}_{next_GW}.csv')
df.head(20)
# Out:
#         web_name     id  element_type  form  points_per_game  \
# 0       Ødegaard    7.0             3   8.8              6.6
# 1       Trippier  357.0             2   9.2              7.0
# 2      De Bruyne  301.0             3   2.2              5.6
# 3        Haaland  318.0             4   5.8              8.4
# 4     Martinelli   19.0             3   5.8              5.6
# 5           Kane  427.0             4   6.4              6.7
# 6        Almirón  369.0             3   4.0              5.7
# 7          White   10.0             2   4.5              4.7
# 8           Shaw  332.0             2   7.2              4.4
# 9        Andreas  346.0             3   3.0              3.8
# 10      Mitrović  210.0             4   4.0              5.1
# 11          Ward  254.0             1   2.0              3.6
# 12  Arrizabalaga  133.0             1   5.0              4.9
# 13    N.Williams  295.0             2   1.0              1.8
# 14     Patterson  197.0             2   0.2              1.8
#
#     predicted_points_21  predicted_points_mean  predicted_points_21_raw  \
# 0                  7.13                   8.84                     7.13
# 1                 10.58                   8.46                    10.58
# 2                  5.11                   7.89                     5.11
# 3                  6.90                   7.87                     6.90
# 4                  7.16                   7.33                     7.16
# 5                  8.31                   6.77                     8.31
# 6                  7.63                   6.37                     7.63
# 7                  5.53                   6.14                     5.53
# 8                  4.32                   4.82                     4.32
# 9                  4.74                   4.40                     4.74
# 10                 4.02                   4.24                     4.02
# 11                 2.43                   3.70                     2.43
# 12                 2.83                   3.47                     2.83
# 13                 0.32                   0.38                     1.58
# 14                 0.00                   0.00                     3.25
#
#     predicted_points_mean_raw
# 0                        8.84
# 1                        8.46
# 2                        7.89
# 3                        7.87
# 4                        7.33
# 5                        6.77
# 6                        6.37
# 7                        6.14
# 8                        4.82
# 9                        4.40
# 10                       4.24
# 11                       3.70
# 12                       3.47
# 13                       1.86
# 14                       2.91
