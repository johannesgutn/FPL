# %%
from main_functions import *
# Out:
# 2023-02-03 16:40:13.060940: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# This shows the preductions for all the players
df = pd.read_csv(f'player_data/player_data_{season}_{last_GW}.csv')
df.head(20)
# Out:
#       web_name opponent_22  predicted_points_22 opponent_23  \
# 0    Fernandes         LEE                16.89         LEE
# 1    De Bruyne         TOT                 6.96         ARS
# 2     Harrison         NFO                12.17         MUN
# 3      Haaland         TOT                 6.14         AVL
# 4     Ødegaard         EVE                 6.54         BRE
# 5       Gnonto         NFO                11.30         MUN
# 6     Rashford         CRY                13.32         LEE
# 7         Saka         EVE                 5.79         MCI
# 8     Aaronson         NFO                10.50         MUN
# 9        Wöber         MUN                10.60         MUN
# 10       Salah         WOL                 7.33         EVE
# 11  Martinelli         EVE                 5.82         MCI
# 12      Nelson         EVE                 5.57         BRE
# 13      Mahrez         TOT                 5.57         AVL
# 14      Antony         CRY                13.87         LEE
# 15    Trossard         EVE                 6.59         MCI
# 16     Meslier         MUN                 9.57         MUN
# 17    Grealish         TOT                 4.90         AVL
# 18      Ayling         MUN                 9.39         MUN
# 19     Struijk         MUN                 8.82         MUN
#
#     predicted_points_23 opponent_24  predicted_points_24 opponent_25  \
# 0                  8.00         LEI                 8.49           0
# 1                 13.12         NFO                 6.95         BOU
# 2                  6.23         EVE                 6.64         SOU
# 3                 11.76         NFO                 6.93         BOU
# 4                 10.59         AVL                 6.82         LEI
# 5                  6.22         EVE                 6.45         SOU
# 6                  6.51         LEI                 6.67           0
# 7                  9.95         AVL                 6.33         LEI
# 8                  5.59         EVE                 6.42         SOU
# 9                  5.78         EVE                 6.06         SOU
# 10                 6.98         NEW                 5.09         CRY
# 11                 9.50         AVL                 5.59         LEI
# 12                 9.38         AVL                 5.14         LEI
# 13                11.85         NFO                 5.09         BOU
# 14                 5.80         LEI                 6.92           0
# 15                 8.25         AVL                 5.15         LEI
# 16                 4.44         EVE                 5.55         SOU
# 17                10.50         NFO                 5.38         BOU
# 18                 4.78         EVE                 5.31         SOU
# 19                 3.98         EVE                 5.53         SOU
#
#     predicted_points_25 opponent_26  ...  opp_influence_conceded_pg_atk_last5  \
# 0                  0.00         LIV  ...                                177.6
# 1                  7.35         NEW  ...                                171.0
# 2                  6.54         CHE  ...                                 99.4
# 3                  7.67         NEW  ...                                171.0
# 4                  5.75         BOU  ...                                141.2
# 5                  6.03         CHE  ...                                 99.4
# 6                  0.00         LIV  ...                                177.6
# 7                  5.41         BOU  ...                                141.2
# 8                  6.11         CHE  ...                                 99.4
# 9                  6.19         CHE  ...                                 99.4
# 10                 7.42         MUN  ...                                114.3
# 11                 5.69         BOU  ...                                141.2
# 12                 4.97         BOU  ...                                141.2
# 13                 4.72         NEW  ...                                171.0
# 14                 0.00         LIV  ...                                118.8
# 15                 5.18         BOU  ...                                141.2
# 16                 5.37         CHE  ...                                 99.4
# 17                 4.82         NEW  ...                                171.0
# 18                 5.15         CHE  ...                                 82.2
# 19                 5.31         CHE  ...                                 99.4
#
#     opp_creativity_conceded_pg_atk_last5  opp_threat_conceded_pg_atk_last5  \
# 0                                  159.5                             212.4
# 1                                  162.7                             185.6
# 2                                  108.8                             116.0
# 3                                  162.7                             185.6
# 4                                  134.0                             143.8
# 5                                  108.8                             116.0
# 6                                  159.5                             212.4
# 7                                  134.0                             143.8
# 8                                  108.8                             116.0
# 9                                  108.8                             116.0
# 10                                 121.9                             153.8
# 11                                 134.0                             143.8
# 12                                 134.0                             143.8
# 13                                 162.7                             185.6
# 14                                  97.3                             108.4
# 15                                 134.0                             143.8
# 16                                 108.8                             116.0
# 17                                 162.7                             185.6
# 18                                  77.0                             118.2
# 19                                 108.8                             116.0
#
#     opp_bps_conceded_pg_atk_last5  opp_total_points_conceded_pg_def_last5  \
# 0                           132.2                                    36.4
# 1                           129.2                                    20.2
# 2                            75.4                                    14.2
# 3                           129.2                                    20.2
# 4                           107.8                                    19.0
# 5                            75.4                                    14.2
# 6                           132.2                                    36.4
# 7                           107.8                                    19.0
# 8                            75.4                                    14.2
# 9                            75.4                                    14.2
# 10                           87.6                                    23.0
# 11                          107.8                                    19.0
# 12                          107.8                                    19.0
# 13                          129.2                                    20.2
# 14                           80.6                                    20.6
# 15                          107.8                                    19.0
# 16                           75.4                                    14.2
# 17                          129.2                                    20.2
# 18                           69.0                                     8.8
# 19                           75.4                                    14.2
#
#     opp_ict_index_conceded_pg_def_last5  opp_influence_conceded_pg_def_last5  \
# 0                                  27.0                                160.5
# 1                                  20.0                                130.4
# 2                                  14.1                                 87.7
# 3                                  20.0                                130.4
# 4                                  14.7                                 96.0
# 5                                  14.1                                 87.7
# 6                                  27.0                                160.5
# 7                                  14.7                                 96.0
# 8                                  14.1                                 87.7
# 9                                  14.1                                 87.7
# 10                                 16.5                                 99.8
# 11                                 14.7                                 96.0
# 12                                 14.7                                 96.0
# 13                                 20.0                                130.4
# 14                                 15.4                                 82.6
# 15                                 14.7                                 96.0
# 16                                 14.1                                 87.7
# 17                                 20.0                                130.4
# 18                                 13.3                                 85.8
# 19                                 14.1                                 87.7
#
#     opp_creativity_conceded_pg_def_last5  opp_threat_conceded_pg_def_last5  \
# 0                                   67.8                              41.2
# 1                                   44.5                              25.8
# 2                                   29.2                              23.4
# 3                                   44.5                              25.8
# 4                                   26.2                              24.4
# 5                                   29.2                              23.4
# 6                                   67.8                              41.2
# 7                                   26.2                              24.4
# 8                                   29.2                              23.4
# 9                                   29.2                              23.4
# 10                                  34.8                              29.2
# 11                                  26.2                              24.4
# 12                                  26.2                              24.4
# 13                                  44.5                              25.8
# 14                                  42.8                              28.4
# 15                                  26.2                              24.4
# 16                                  29.2                              23.4
# 17                                  44.5                              25.8
# 18                                  33.3                              13.2
# 19                                  29.2                              23.4
#
#     opp_bps_conceded_pg_def_last5
# 0                           154.4
# 1                           125.6
# 2                            79.8
# 3                           125.6
# 4                            91.4
# 5                            79.8
# 6                           154.4
# 7                            91.4
# 8                            79.8
# 9                            79.8
# 10                           99.4
# 11                           91.4
# 12                           91.4
# 13                          125.6
# 14                           88.8
# 15                           91.4
# 16                           79.8
# 17                          125.6
# 18                           61.6
# 19                           79.8
#
# [20 rows x 157 columns]

# %%
# This shows your team
df = pd.read_csv(f'ml_team/ml_team_{season}_{next_GW}.csv')
df.head(20)
# Out:
#         web_name     id  element_type  form  points_per_game  \
# 0      De Bruyne  301.0             3   3.5              5.6
# 1        Haaland  318.0             4   6.8              8.9
# 2         Gnonto  619.0             4   4.3              2.6
# 3       Rashford  335.0             3   6.3              5.4
# 4     Martinelli   19.0             3   2.0              5.4
# 5           Kane  427.0             4   7.2              6.7
# 6       Trippier  357.0             2   8.5              7.0
# 7          White   10.0             2   4.0              4.4
# 8   Arrizabalaga  133.0             1   5.5              5.2
# 9           Shaw  332.0             2   1.3              4.1
# 10       Andreas  346.0             3   2.7              3.7
# 11       Almirón  369.0             3   3.0              5.6
# 12          Ward  254.0             1   1.5              3.5
# 13    N.Williams  295.0             2   1.0              1.8
# 14     Patterson  197.0             2   0.0              1.8
#
#     predicted_points_22  predicted_points_mean  predicted_points_22_raw  \
# 0                  6.96                   8.19                     6.96
# 1                  6.14                   7.42                     6.14
# 2                 11.30                   7.01                    11.30
# 3                 13.32                   6.79                    13.32
# 4                  5.82                   6.52                     5.82
# 5                  3.74                   5.67                     3.74
# 6                  8.34                   5.61                     8.34
# 7                  4.92                   4.77                     4.92
# 8                  4.20                   4.52                     4.20
# 9                  9.72                   4.48                     9.72
# 10                 4.96                   4.38                     4.96
# 11                 5.75                   4.07                     5.75
# 12                 4.97                   3.84                     4.97
# 13                 1.10                   0.90                     3.77
# 14                 0.00                   0.00                     2.91
#
#     predicted_points_mean_raw
# 0                        8.19
# 1                        7.42
# 2                        7.01
# 3                        6.79
# 4                        6.52
# 5                        5.67
# 6                        5.61
# 7                        4.77
# 8                        4.52
# 9                        4.48
# 10                       4.38
# 11                       4.07
# 12                       3.84
# 13                       3.09
# 14                       3.18
